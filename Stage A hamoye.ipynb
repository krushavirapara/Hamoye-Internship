# %%
import pandas as pd

# %%
df=pd.read_csv("FoodBalanceSheets_E_africa_NOFLAG.csv")

# %%
df.head(15)
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 0           4  Algeria       2501                Population           511
# 1           4  Algeria       2501                Population          5301
# 2           4  Algeria       2901               Grand Total           664
# 3           4  Algeria       2901               Grand Total           674
# 4           4  Algeria       2901               Grand Total           684
# 5           4  Algeria       2903          Vegetal Products           664
# 6           4  Algeria       2903          Vegetal Products           674
# 7           4  Algeria       2903          Vegetal Products           684
# 8           4  Algeria       2941           Animal Products           664
# 9           4  Algeria       2941           Animal Products           674
# 10          4  Algeria       2941           Animal Products           684
# 11          4  Algeria       2905  Cereals - Excluding Beer          5511
# ...

# %%
df.Item.unique()
# Out:
# array(['Population', 'Grand Total', 'Vegetal Products', 'Animal Products',
#        'Cereals - Excluding Beer', 'Wheat and products',
#        'Rice and products', 'Barley and products', 'Maize and products',
#        'Rye and products', 'Oats', 'Millet and products',
#        'Sorghum and products', 'Cereals, Other', 'Starchy Roots',
#        'Cassava and products', 'Potatoes and products', 'Sweet potatoes',
#        'Yams', 'Roots, Other', 'Sugar Crops', 'Sugar cane', 'Sugar beet',
#        'Sugar & Sweeteners', 'Sugar (Raw Equivalent)',
#        'Sweeteners, Other', 'Honey', 'Pulses', 'Beans', 'Peas',
#        'Pulses, Other and products', 'Treenuts', 'Nuts and products',
#        'Oilcrops', 'Soyabeans', 'Groundnuts (Shelled Eq)',
#        'Sunflower seed', 'Rape and Mustardseed', 'Cottonseed',
#        'Coconuts - Incl Copra', 'Sesame seed',
#        'Olives (including preserved)', 'Oilcrops, Other',
#        'Vegetable Oils', 'Soyabean Oil', 'Groundnut Oil',
# ...

# %%
g=df.groupby("Item")
for key,df in g:
    print(key)
    print(df)
# Out:
# Alcohol, Non-Food
#        Area Code      Area  Item Code               Item  Element Code  \
# 961            4   Algeria       2659  Alcohol, Non-Food          5511
# 962            4   Algeria       2659  Alcohol, Non-Food          5611
# 963            4   Algeria       2659  Alcohol, Non-Food          5072
# 964            4   Algeria       2659  Alcohol, Non-Food          5301
# 965            4   Algeria       2659  Alcohol, Non-Food          5154
# ...          ...       ...        ...                ...           ...
# 60591        181  Zimbabwe       2659  Alcohol, Non-Food          5072
# 60592        181  Zimbabwe       2659  Alcohol, Non-Food          5911
# 60593        181  Zimbabwe       2659  Alcohol, Non-Food          5301
# 60594        181  Zimbabwe       2659  Alcohol, Non-Food          5154
# 60595        181  Zimbabwe       2659  Alcohol, Non-Food          5170
#
#                         Element         Unit  Y2014  Y2015  Y2016  Y2017  \
# ...

# %%
#11.
g.sum()
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %%
#12.
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
#13.
print(df.Y2016.isnull().sum())
df["Y2016"].isnull().sum()/df["Y2016"].sum()*100
# Out:
# 1535
# 0.01892148135624223

# %%
#14.
print(df["Element Code"].corr(df["Y2014"]))
print(df["Element Code"].corr(df["Y2015"]))
print(df["Element Code"].corr(df["Y2016"]))
print(df["Element Code"].corr(df["Y2017"]))
print(df["Element Code"].corr(df["Y2018"]))
# Out:
# 0.024456819495221747
# 0.02388919930163993
# 0.023443997584961445
# 0.02425400776004577
# 0.02427857195351958

# %%
#15.=2017 16.=1931
f=df.groupby("Element")
f.sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
#17.
h=df["Element"],df["Y2018"]
h=pd.DataFrame(h)
h.head()
h.groupby(["Element"])
for key,df in h:
    print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-4b0a650ba984> in <module>
#       2 h=pd.DataFrame(h)
#       3 h.head()
# ----> 4 h.groupby(["Element"])
#       5 for key,df in h:
#       6     print(df)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6725             squeeze=squeeze,
#    6726             observed=observed,
# -> 6727             dropna=dropna,
#    6728         )
#    6729
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     566                 observed=observed,
#     567                 mutated=self.mutated,
# --> 568                 dropna=self.dropna,
# ...

# %%
#19.
j=df.groupby(["Area"])
j=pd.DataFrame(j)
j.head()

#g=j.groupby(["Element"])
# Out:
#               0                                                  1
# 0       Algeria        Area Code     Area  Item Code           ...
# 1        Angola        Area Code    Area  Item Code           I...
# 2         Benin        Area Code   Area  Item Code           It...
# 3      Botswana        Area Code      Area  Item Code          ...
# 4  Burkina Faso        Area Code          Area  Item Code      ...

# %%
#20.
df["Area"].value_counts().count()
# Out:
# 49
